# %%
import numpy as np
import pandas as pd
from datetime import datetime
import datetime as dt

# %%
r_results=pd.read_excel("comparacion resultados vs MIF.xlsx",sheet_name="datos",index_col=1)

# %%
mif_results=pd.read_excel("PITSS abril version comparacion.xlsx",sheet_name="Hoja3",index_col=2)

# %%
r_results
# Out:
#              No. Orden  Year Quarter  Month  Day                 Categoría  \
# N° de serie
# 9HB334888        64026  2019   Qtr 1  March    4         INSTALACION NUEVA
# 0AGD461524       64377  2019   Qtr 1  March    5                CORRECTIVO
# 0BG2951668       65273  2019   Qtr 1  March   11  MANTENIMIENTO PREVENTIVO
# 0BPB110617       65752  2019   Qtr 1  March   13                CORRECTIVO
# 0BPB110653       65760  2019   Qtr 1  March   13                CORRECTIVO
#  09HB914002      65963  2019   Qtr 1  March   14         INSTALACION NUEVA
# 0VGW686533       66303  2019   Qtr 1  March   15                CORRECTIVO
# C7X376533        66652  2019   Qtr 1  March   19         INSTALACION NUEVA
# 0BG0971716       66854  2019   Qtr 1  March   20                CORRECTIVO
# 0EX9310036       66935  2019   Qtr 1  March   21                CORRECTIVO
# 0RXD138712       66971  2019   Qtr 1  March   21                CORRECTIVO
# ...

# %%
mif_results
# Out:
#                        0     AUXILIAR     MES  SERV  INCIDENT_N  \
# SERIE
# 9HB334888     9HB3348883   9HB3348881  ABR-19     1     2003187
# 0AGD461524   0AGD4615245  0AGD4615241  ABR-19     1     2004303
# 0BPB110617  0BPB11061712  0BPB1106171  ABR-19     1     2007823
# 0BPB110653  0BPB11065313  0BPB1106531  ABR-19     1     2008499
# AAQ100656    AAQ10065614   AAQ1006561  ABR-19     1     2009423
# 0VGW686533  0VGW68653315  0VGW6865331  ABR-19     1     2010007
# 0BG0971716  0BG097171620  0BG09717161  ABR-19     1     2012347
# 09BR546320  09BR54632021  09BR5463201  ABR-19     1     2012769
# 0EX9310036  0EX931003621  0EX93100361  ABR-19     1     2012779
# 08TB592525  08TB59252521  08TB5925251  ABR-19     1     2012931
# 09BR546326  09BR54632621  09BR5463261  ABR-19     1     2012945
# 9HB914002    9HB91400221   9HB9140021  ABR-19     1     2012997
# 0BG2948893  0BG294889322  0BG29488931  ABR-19     1     2013303
# ...

# %%
# mif in R
heck_vector=[]
for i in np.arange(952):
    try:
        mif_results.loc[r_results.index[i]]
        try:
            np.shape(mif_results.loc[r_results.index[i]])[1]
            for k in np.arange(np.shape(mif_results.loc[r_results.index[i]])[0]):
                datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)
                if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].iloc[k].F_INICIO[0:10],'%d/%m/%Y')):
                    datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)                    
                    if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].iloc[k].F_INICIO[0:10],'%d/%m/%Y')+dt.timedelta(days=1)):      
                        datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)
                        if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].iloc[k].F_INICIO[0:10],'%d/%m/%Y')-dt.timedelta(days=1)):
                            if(k==np.shape(mif_results.loc[r_results.index[i]])[0]):
                                check_vector.append('all false')
                            else:
                                pass
                        else:
                            check_vector.append('true -1')       
                            break
                    else:
                        check_vector.append('true +1')  
                        break
                else:
                    check_vector.append('true')
                    break
        except:
            datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)
            if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].F_INICIO[0:10],'%d/%m/%Y')):
                datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)
                if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].F_INICIO[0:10],'%d/%m/%Y')+dt.timedelta(days=1)):
                    datestring=str(r_results.iloc[i].Year)+'-'+r_results.iloc[i].Month+'-'+str(r_results.iloc[i].Day)
                    if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.loc[r_results.index[i]].F_INICIO[0:10],'%d/%m/%Y')-dt.timedelta(days=1)):
                        check_vector.append('all false')
                    else:
                        check_vector.append('true -1')
                else:
                    check_vector.append('true +1')
            else:
                check_vector.append('true')
    except:
        check_vector.append('not found')

# %%
np.size(np.where(np.array(check_vector)=="not found"))
# Out:
# 208

# %%
#R in MIF
check_vector=[]
for i in np.arange(840):
    try:
        r_results.loc[mif_results.index[i]]
        try:
            np.shape(r_results.loc[mif_results.index[i]])[1]
            for k in np.arange(np.shape(r_results.loc[mif_results.index[i]])[0]):
                datestring=str(r_results.loc[mif_results.index[i]].iloc[k].Year)+'-'+r_results.loc[mif_results.index[i]].iloc[k].Month+'-'+str(r_results.loc[mif_results.index[i]].iloc[k].Day)
                if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')):
                    if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')+dt.timedelta(days=1)):
                        if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')-dt.timedelta(days=1)):
                            if(k==np.shape(r_results.loc[mif_results.index[i]])[0]):
                                check_vector.append('all false')
                            else:
                                pass
                        else:
                            check_vector.append('true -1')
                            break
                    else:
                        check_vector.append('true +1')
                        break
                else:
                    check_vector.append('true')
                    break
        except:
            datestring=str(r_results.loc[mif_results.index[i]].Year)+'-'+r_results.loc[mif_results.index[i]].Month+'-'+str(r_results.loc[mif_results.index[i]].Day)
            if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')):
                if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')+dt.timedelta(days=1)):
                    if not(datetime.strptime(datestring, '%Y-%B-%d')==datetime.strptime(mif_results.iloc[i].F_INICIO[0:10],'%d/%m/%Y')-dt.timedelta(days=1)):
                        check_vector.append('all false')
                    else:
                        check_vector.append('true -1')
                else:
                    check_vector.append('true +1')
            else:
                check_vector.append('true')
    except:
        check_vector.append('not found')

# %%
np.size(np.where(np.array(check_vector)=="not found"))
# Out:
# 54
